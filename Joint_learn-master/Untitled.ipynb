# %%
import torch
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:800"
torch.cuda.empty_cache()
# !python main.py --task atis --model_type joint_bert --model_dir ./atis_model/joint_bert --do_train
# Out:
# 12/20/2023 19:43:36 - INFO - data_loader - loading data file from .\data\atis\cached_atis_train_bert-base-uncased_50.zip
# 12/20/2023 19:43:36 - INFO - data_loader - loading data file from .\data\atis\cached_atis_dev_bert-base-uncased_50.zip
# 12/20/2023 19:43:36 - INFO - data_loader - loading data file from .\data\atis\cached_atis_test_bert-base-uncased_50.zip
# Some weights of JointBert were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['intent_classifier.fc_layer.bias', 'slot_classifier.fc_layer.bias', 'intent_classifier.fc_layer.weight', 'slot_classifier.fc_layer.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
